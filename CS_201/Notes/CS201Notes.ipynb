# %% [markdown]
# ## Vocabulary
#
# - API - application programming interface
# - Array - memory mapped to structure. Fixed size, random access
# - AI - machine learning and…
# - Boolean - True, False: 1 bit to represent 2 values?
# - Bit - 0, 1, Binary DigIT
# - Class - factory for creating objects
# - Collections and Collection - See java.util.* for details
# - Debugging - a key skill in making your programs run correctly
# - Database - from SQL to NO-SQL
#     - from data to information

# %% [markdown]
# ## Java Overview
# - Object-oriented, strongly typed language
# - Compiled from .java source code into byte code
# - Byte code in .class file executed by JVM, Java Virtual Machine
# - VS Code does this for us
# - Statically and strongly typed, meaning:
#     - Variables have type identified in source code
#         - Strong and static typing, compile time errors
#         - Python is dynamically typed, runtime errors
#     - Variables have a name, a type, and a value
# - What is a class?
#     - Class is a programming construct
#         - Encapsulates state and behavior
#     - Object: instance of a class
#         - Class is a template, blueprint, object factory
#     - Class methods operate on objects
#         - str.length(), scn.next()

# %% [markdown]
# ## Revisiting the Word Counting Program from August 24th
# - Primitive int variable
#     - Ex: “int wcount = 0” this code can be read as int wcount gets 0
# - Primitive boolean (expression)
#     - Ex: “while (s.hasNext()) {”
# - Object references
#     - Ex: list
# - All types that are in blue that start with a capital letter are classes
#     - Ex: “String”
# - In Java you have to end a statement in semi-colons
# - In Java you use curly-braces “{}” for code blocks compared to Python where indents are utilized.
#     - However, indents can still be used alongside of curly braces “{}” to promote organization and ease of reading
# - Whenever you have a while loop, if statement, etc. always put the curly braces
# ### Java Primitives and Objects
# - Java has two different kinds of values/variables
#     - Primitives: int, double, char, boolean, long,...
#     - Objects: pointers/references to object/memory
# - Primitive types: ranges
#     - Ex: “Integer.MIN_VALUE”
#         - Integer is a class name as shown by it being capitalized
#     - Ex: “Integer.MAX_VALUE”
#     - Ex: “Double.MIN_VALUE”
#     - Ex: “Double.MAX_VALUE”
# - Primitive types: variable holds a value
#     - Int, long: common integer types
#     - double: common decimal number type
#     - boolean: true or false
#     - char: ‘z’, ‘!’; number that prints as a character
#         - Note the single ‘quotes’
# - Object types: variables holds a reference
#     - Astring, Scanner ArrayList (array), URL
#         - Variable stores reference or pointer to an object
#         - The value is like an address in memory
#     - Typically call new to create an object, store reference to access the object
#         - Strings are special
#         - See dot notation in file-reading program
#
# | +, -             |                   |
# |------------------|-------------------|
# |                  |                   |
#
# - Primitive type boolean in Java
#     - Values: true, false, short-circuit evaluation
#     - Ex: “boolean x = 1 == 1” → “x ==> true”
# - From primitives to objects/references
#     - All variables have: name, type, variable
#     - All expressions have: type, variable
# - Object variable: reference, pointer
#     - Differences: == and .equals
#     - Ex:
#         - “String s = new String(“Duke”)”
#         - “String t = new String(“Duke”)”
#         - “if (s == t)” {do they label the same box} ← False
#         - “if (s.equals(t))” {are the contents the same} ← True
#         - // only one statement is true
#     - Ex:
#         - “String s = new String(“Duke”)”
#         - “String t = s;
#         - “if (s == t)” {do they label the same box} ← True
#         - “if (s.equals(t))” {are the contents the same} ← True
#         - // both statements are true
#
# - Integer is a class
# - int is a primitive

# %% [markdown]
# ## Arrays in Java
# - Array: fixed size, random access
#     - Indexed starting at 0
#         - Int[] a = new int[5];
#         - a[0] = 4;
#         - a[4] = 7;
#         - System.out.println(Arrays.toString(a));
#         - Result: 4 0 0 0 7
#     - Looping to access array values:
#         - Indexed for-loop
#             - for (int k=0;k<a.length; K++) {
#                 - System.out.print(a[k] +” ”);
#             - }
#         - For-each loop
#             - System.out.println();
#             - For (int v : a) {
#                 - System.out.print(v+” “);
#             - }
# ## Classes in Java:
# - Class is blueprint for creating objects
#     - Each object is different, blueprint same
#     - Ex: String class: "hello", "Duke!"
# - Class encapsulates state/behavior
#     - String is array of char values
#     - State is the "innards” of object
#         - State specified by instance variables, aka fields
#         - Specific to each object instance
#         - Best practice that state is private
#     - Behavior is how to interact with it
# - String objects are immutable - once created they can never change
# - State can be accessed
# - State can’t change
# - String has getter methods
#     - Access state, different kinds of access
#         - Length of string: .length()
#         - Character at index: .charAt(k)
#         - Substring: .substring(first, last)
#         - Search for char or string: .indexOf(x)

# %% [markdown]
# ## How to avoid duplicates
# - Problem statement: count each word once
#     - How to avoid duplicates?
# - Transform input: no duplicates
# - Alternative: first occurence only

# %% [markdown]
# ### transform input array: no duplicates
# - Create list with no duplicates
#     - Why ArrayList and not array?
#     Next? HashSet is a good alternative

# %%
ArrayList<String> list = new ArrayList<>();
for(string s : a) {
    if (! list.contains(s)) list.add(s);
}

# %% [markdown]
# ### HashSet Method for no duplicates
# - HashSet<String> or ArrayList<String>
#     - both support .add, .size, .contains, and more
#     - HashSet doesn't store duplicates, so there is no need to check
# - Access via import java.util.*; or java.util.HashSet;

# %%
HashSet<String> set = new HashSet <>();
for (String s : a) set.add(s);
System.out.printf("%d and %d/n", a.length, set.size());

# %% [markdown]
# ArrayList – grows, iterable, indexable
# - .contains(elt) may look at every element: linear
# HashSet – grows, iterable, not indexable
# - .contains(elt) is constant time
#     - 10, 100, 1000, or a million elements? Same time
# Both support .clear, .addAll, .remove
#     - And many more methods

# %% [markdown]
# ArrayList.asList(...) returns List<String>
# - immutable list, convenience, stores values
# - Can store String, Object, Person201
# - Cannot store int, double, boolean

# %%
String[] arr = {"a", "b", "c"};
List<String> alist = Arrays.asList(arr);
ArrayList<String> aa = new ArrayList<>(alist);
aa.addAll(alist);
HashSet<String> hset = new HashSet<>(alist);
hset.addAll(alist);

# %% [markdown]
# ### What is a Collection?
# public interface Collection<E>
# extends Iterable<E>
# - A collection represents a group of objects, known as its elements. Some collections allow duplicate elements and others do not.
# - Collections specify an API: methods and how they work together.
#     - For example, ".add" and ".addAll"

# %% [markdown]
# - private, helper method for public .add
#     - grow doubles size of Object[] elementData (see example below)

# %%
private void add(E e, Object[] elementData, int s) {
    if (s == elementData.length) {
        elementData = grow();
    }
    elementData[s] = e;
    size = s + 1;
    
}

# %% [markdown]
# ### Growing internal array when needed
# - When internal array full? Double size and copy
#     - From 128 to 256 to 512 …

# %%
private void checkSize() {
    if (mySize >= myStorage.length) {
        String[] storage = new String[(int)(myStorage.length * 2)];
        System.arraycopy(myStorage, 0, storage, 0, myStorage.length);
        myStorage = storage;
    }
}
